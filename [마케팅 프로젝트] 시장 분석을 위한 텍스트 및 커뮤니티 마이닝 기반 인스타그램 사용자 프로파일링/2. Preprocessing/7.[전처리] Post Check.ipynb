# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjing2/SJ_project/blob/master/%5B%EB%A7%88%EC%BC%80%ED%8C%85%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%5D%20%EC%8B%9C%EC%9E%A5%20%EB%B6%84%EC%84%9D%EC%9D%84%20%EC%9C%84%ED%95%9C%20%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%B0%8F%20%EC%BB%A4%EB%AE%A4%EB%8B%88%ED%8B%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D%20%EA%B8%B0%EB%B0%98%20%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8%20%EC%82%AC%EC%9A%A9%EC%9E%90%20%ED%94%84%EB%A1%9C%ED%8C%8C%EC%9D%BC%EB%A7%81/2.%20Preprocessing/7.%5B%EC%A0%84%EC%B2%98%EB%A6%AC%5D%20Post%20Check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd

# %%
# 경로
df = pd.read_csv('/content/gdrive/My Drive/프로젝트/cc_post2/cc_post2.csv', index_col=[0])

# %%
# cc_post2 확인(88,213개 확인 완료)
df
# Out:
#                        insta_id    inner_id  ...        crawling_time team_idx
# shortcode                                    ...
# CDoeTIvFOC9  yoonseo_park_flord    12457961  ...  2020-09-05 08:25:56        4
# CDjdMIpF4ua  yoonseo_park_flord    12457961  ...  2020-09-05 08:25:56        4
# CDjbmy3FHae  yoonseo_park_flord    12457961  ...  2020-09-05 08:25:56        4
# CDbOBjYlc8n  yoonseo_park_flord    12457961  ...  2020-09-05 08:25:57        4
# B1LWF8jpmZM      romantic2wheel    24996948  ...  2020-09-05 08:25:57        4
# ...                         ...         ...  ...                  ...      ...
# BA6ksSIO7Z7          baboheejin  2714923820  ...  2020-09-06 07:24:51        4
# BA32YqrO7R0          baboheejin  2714923820  ...  2020-09-06 07:24:52        4
# BA2V74-O7RG          baboheejin  2714923820  ...  2020-09-06 07:24:52        4
# BA2M_NBO7d6          baboheejin  2714923820  ...  2020-09-06 07:24:52        4
# BA2L55lu7bh          baboheejin  2714923820  ...  2020-09-06 07:24:52        4
#
# [88213 rows x 12 columns]
