# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjing2/SJ_project/blob/master/%5B%EB%A7%88%EC%BC%80%ED%8C%85%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%5D%20%EC%8B%9C%EC%9E%A5%20%EB%B6%84%EC%84%9D%EC%9D%84%20%EC%9C%84%ED%95%9C%20%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%B0%8F%20%EC%BB%A4%EB%AE%A4%EB%8B%88%ED%8B%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D%20%EA%B8%B0%EB%B0%98%20%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8%20%EC%82%AC%EC%9A%A9%EC%9E%90%20%ED%94%84%EB%A1%9C%ED%8C%8C%EC%9D%BC%EB%A7%81/2.%20Preprocessing/12.%5B%EC%A0%84%EC%B2%98%EB%A6%AC%5D%20Post%20Result%20Check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd

# %%
cc_df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Final/cc_post.csv')
cc_df
# Out:
#           shortcode    insta_id  ...        crawling_time team_idx
# 0       CEasJz1JPgQ   jjjjy_o.o  ...  2020-08-31 03:32:07        4
# 1       CEY3iR2pr-l   jjjjy_o.o  ...  2020-08-31 03:32:08        4
# 2       CEYOgJUJ1KR   jjjjy_o.o  ...  2020-08-31 03:32:08        4
# 3       CEWyKvgJE1C   jjjjy_o.o  ...  2020-08-31 03:32:08        4
# 4       CEWde7hJDk1   jjjjy_o.o  ...  2020-08-31 03:32:08        4
# ...             ...         ...  ...                  ...      ...
# 110583  BA6ksSIO7Z7  baboheejin  ...  2020-09-06 07:24:51        4
# 110584  BA32YqrO7R0  baboheejin  ...  2020-09-06 07:24:52        4
# 110585  BA2V74-O7RG  baboheejin  ...  2020-09-06 07:24:52        4
# 110586  BA2M_NBO7d6  baboheejin  ...  2020-09-06 07:24:52        4
# 110587  BA2L55lu7bh  baboheejin  ...  2020-09-06 07:24:52        4
#
# [110588 rows x 13 columns]

# %%
gs_df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Final/gs_post.csv')
gs_df
# Out:
#           shortcode   insta_id  ...        crawling_time team_idx
# 0       CB-kragHtB1  mint_seul  ...  2020-09-05 01:07:03      4.0
# 1       CBRjjjLHBeH  mint_seul  ...  2020-09-05 01:07:03      4.0
# 2       CBRjPgnHo56  mint_seul  ...  2020-09-05 01:07:03      4.0
# 3       CBMk6R0lqQ4  mint_seul  ...  2020-09-05 01:07:03      4.0
# 4       CBIKM-HnnWc  mint_seul  ...  2020-09-05 01:07:03      4.0
# ...             ...        ...  ...                  ...      ...
# 131568  CD_eeLhlqs3   mubwatna  ...  2020-09-01 13:00:57      4.0
# 131569  CD8Sr4dlRiu   mubwatna  ...  2020-09-01 13:00:57      4.0
# 131570  CDxzTHih8zy   mubwatna  ...  2020-09-01 13:00:57      4.0
# 131571  CDxv59lBVWt   mubwatna  ...  2020-09-01 13:00:57      4.0
# 131572  CDxsWelhnXO   mubwatna  ...  2020-09-01 13:00:57      4.0
#
# [131573 rows x 13 columns]

# %%
gw_df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Final/gw_post.csv')
gw_df
# Out:
#           shortcode       insta_id  ...        crawling_time team_idx
# 0       CEgIUOLJaaD         leeclo  ...  2020-08-31 02:30:08        4
# 1       CEVgrcqJV70         leeclo  ...  2020-08-31 02:30:08        4
# 2       CEMRnFepGoy         leeclo  ...  2020-08-31 02:30:08        4
# 3       CEJpiIlJbLu         leeclo  ...  2020-08-31 02:30:08        4
# 4       CD-t4onJ_cb         leeclo  ...  2020-08-31 02:30:08        4
# ...             ...            ...  ...                  ...      ...
# 134522  BtKKo07AM_f  onjeon_coffee  ...  2020-09-05 09:20:28        4
# 134523  BtJHcyYAa8C  onjeon_coffee  ...  2020-09-05 09:20:28        4
# 134524  BtJG3GEgOXd  onjeon_coffee  ...  2020-09-05 09:20:28        4
# 134525  BtJC6L-gwxD  onjeon_coffee  ...  2020-09-05 09:20:28        4
# 134526  BtIOR6aAk2f  onjeon_coffee  ...  2020-09-05 09:20:28        4
#
# [134527 rows x 13 columns]

# %%
jl_df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Final/jl_post.csv')
jl_df
# Out:
#          shortcode              insta_id  ...        crawling_time team_idx
# 0      Bw--6JFFkE1                cyrano  ...  2020-08-31 00:19:27        4
# 1      BrZiJ9gFvdp                cyrano  ...  2020-08-31 00:19:27        4
# 2      BmaLQQbBxjP                cyrano  ...  2020-08-31 00:19:27        4
# 3      Blw0_aSBSWs                cyrano  ...  2020-08-31 00:19:27        4
# 4      BlruAQPhK-h                cyrano  ...  2020-08-31 00:19:27        4
# ...            ...                   ...  ...                  ...      ...
# 87667  BGeiZIjAVYQ  sunny_____sunny_____  ...  2020-09-05 12:42:06        4
# 87668  BGcErMugVZf  sunny_____sunny_____  ...  2020-09-05 12:42:06        4
# 87669  BGcEKr7gVYC  sunny_____sunny_____  ...  2020-09-05 12:42:06        4
# 87670  BGcC1MHgVUQ  sunny_____sunny_____  ...  2020-09-05 12:42:09        4
# 87671  BGcCIQ9AVSQ  sunny_____sunny_____  ...  2020-09-05 12:42:09        4
#
# [87672 rows x 13 columns]

# %%
sd_df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Final/sd_post.csv')
sd_df
# Out:
#           shortcode      insta_id  ...        crawling_time team_idx
# 0       CEHmmappauO  cabbagedoll_  ...  2020-09-04 10:50:05        4
# 1       CEHksXvp7NV  cabbagedoll_  ...  2020-09-04 10:50:05        4
# 2       CDWewZ9pupb  cabbagedoll_  ...  2020-09-04 10:50:05        4
# 3       CDVj9QDJtWf  cabbagedoll_  ...  2020-09-04 10:50:05        4
# 4       CDVf3_hpCwQ  cabbagedoll_  ...  2020-09-04 10:50:05        4
# ...             ...           ...  ...                  ...      ...
# 182850   pvD6-SCtoq      hyemvely  ...  2020-09-05 22:23:28        4
# 182851   ptYSt5CtsT      hyemvely  ...  2020-09-05 22:23:28        4
# 182852   ptKZcKitrP      hyemvely  ...  2020-09-05 22:23:28        4
# 182853   ptC1kcCtjy      hyemvely  ...  2020-09-05 22:23:28        4
# 182854   psfD8Ditm6      hyemvely  ...  2020-09-05 22:23:28        4
#
# [182855 rows x 13 columns]

# %%
cc_df.head(1)
# Out:
#      shortcode   insta_id  inner_id  ... view_count        crawling_time team_idx
# 0  CEasJz1JPgQ  jjjjy_o.o   1582899  ...        NaN  2020-08-31 03:32:07        4
#
# [1 rows x 13 columns]

# %%
gs_df.head(1)
# Out:
#      shortcode   insta_id  inner_id  ... view_count        crawling_time team_idx
# 0  CB-kragHtB1  mint_seul   3233588  ...        NaN  2020-09-05 01:07:03      4.0
#
# [1 rows x 13 columns]

# %%
gw_df.head(1)
# Out:
#      shortcode insta_id  inner_id  ... view_count        crawling_time team_idx
# 0  CEgIUOLJaaD   leeclo    831796  ...        NaN  2020-08-31 02:30:08        4
#
# [1 rows x 13 columns]

# %%
jl_df.head(1)
# Out:
#      shortcode insta_id  inner_id  ... view_count        crawling_time team_idx
# 0  Bw--6JFFkE1   cyrano    114789  ...        NaN  2020-08-31 00:19:27        4
#
# [1 rows x 13 columns]

# %%
sd_df.head(1)
# Out:
#      shortcode      insta_id  ...        crawling_time team_idx
# 0  CEHmmappauO  cabbagedoll_  ...  2020-09-04 10:50:05        4
#
# [1 rows x 13 columns]
