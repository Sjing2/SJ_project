# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjing2/SJ_project/blob/master/%5B%EB%A7%88%EC%BC%80%ED%8C%85%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%5D%20%EC%8B%9C%EC%9E%A5%20%EB%B6%84%EC%84%9D%EC%9D%84%20%EC%9C%84%ED%95%9C%20%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%B0%8F%20%EC%BB%A4%EB%AE%A4%EB%8B%88%ED%8B%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D%20%EA%B8%B0%EB%B0%98%20%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8%20%EC%82%AC%EC%9A%A9%EC%9E%90%20%ED%94%84%EB%A1%9C%ED%8C%8C%EC%9D%BC%EB%A7%81/2.%20Preprocessing/8.%5B%EC%A0%84%EC%B2%98%EB%A6%AC%5D%20Post%20Add%20shortcode(insta_ID).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
word_df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Delete(foreign, over1000)/3. delete_businessword/cc_word.csv')

# %%
word_df
# Out:
#          insta_id  ...                                          next_page
# 0       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# 1       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# 2       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# 3       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# 4       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# ...           ...  ...                                                ...
# 22370  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
# 22371  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
# 22372  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
# 22373  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
# 22374  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
#
# [22375 rows x 13 columns]

# %%
word_df_url = word_df["url"]
word_df_url
# Out:
# 0        https://www.instagram.com/p/CEasJz1JPgQ/
# 1        https://www.instagram.com/p/CEY3iR2pr-l/
# 2        https://www.instagram.com/p/CEYOgJUJ1KR/
# 3        https://www.instagram.com/p/CEWyKvgJE1C/
# 4        https://www.instagram.com/p/CEWde7hJDk1/
#                            ...
# 22370    https://www.instagram.com/p/CDd8XJ4Fm3Y/
# 22371    https://www.instagram.com/p/CDd7qDAlaO3/
# 22372    https://www.instagram.com/p/CDd7U1IFXCu/
# 22373    https://www.instagram.com/p/CDd60iUlSIr/
# 22374    https://www.instagram.com/p/CDdjlfqlZEf/
# Name: url, Length: 22375, dtype: object

# %%
word_df_url[0]
# Out:
# 'https://www.instagram.com/p/CEasJz1JPgQ/'

# %%
word_df_url[0][28:]
# Out:
# 'CEasJz1JPgQ/'

# %%
url_shortcode = []

for i in range(22375):
    url_shortcode.append(word_df_url[i][28:])

url_shortcode
# Out:
# ['CEasJz1JPgQ/',
#  'CEY3iR2pr-l/',
#  'CEYOgJUJ1KR/',
#  'CEWyKvgJE1C/',
#  'CEWde7hJDk1/',
#  'CDn-R0hjf32/',
#  'CD_mUZTjDmF/',
#  'CEV0fH8pqh2/',
#  'CDXig_xjwkc/',
#  'CD54mkCDt68/',
#  'CEVfvMPp17N/',
#  'CC0th3NFEz_/',
#  'CCU5cqijjGS/',
#  'CD0g8ZZDzmI/',
#  'CETvWx9paZk/',
#  'CAmEVaLgDO5/',
#  'CDyrbrcDU2c/',
#  'CDidAN6jUgX/',
#  'CDf0pnnDOJW/',
#  'CETG1a5pCUs/',
#  'CAidJlmgc89/',
#  'B_6bE0oglZg/',
#  'CDQvcJhjZYs/',
#  'CDOsSuVjGPF/',
#  'CB_4zirHkOu/',
#  'CESwMbMpXxU/',
#  'CEA462CpABv/',
#  'B_O3qGGFr2N/',
#  'CDL_tfRjroZ/',
#  'CDLPPWljgej/',
#  'B-Q40rRnVYE/',
#  'B61z1jPCodg/',
#  'B5i50aviYda/',
#  'BxI37HVHD7d/',
#  'CD_YqWXpf7B/',
#  'CD-zmh9Joyu/',
#  'B-4pTcTjE-S/',
#  'B-v9W1KD7Mp/',
#  'B-sCDNDFt0Z/',
#  'CDGNPKaDhvZ/',
#  'BxH10kXlRiV/',
#  'BvwEDRxnDG3/',
#  'BujwEplHX2C/',
#  'Bub9d1yHNkD/',
#  'CD8y4ybJaDF/',
#  'CDz0J-ApDOM/',
#  'CDx01EbpjTj/',
#  'B-lVqqpj2Dz/',
#  'CCslpLzDssV/',
#  'BqpTjrpnjDe/',
#  'CDxfyBppJno/',
#  'B9WuE0qlYPk/',
# ...

# %%
len(url_shortcode)
# Out:
# 22375

# %%
url_shortcode[0]
# Out:
# 'CEasJz1JPgQ/'

# %%
url_shortcode[0][:-1]
# Out:
# 'CEasJz1JPgQ'

# %%
shortcode = []

for i in range(22375):
    shortcode.append(url_shortcode[i][:-1])

print(shortcode)
# Out:
# ['CEasJz1JPgQ', 'CEY3iR2pr-l', 'CEYOgJUJ1KR', 'CEWyKvgJE1C', 'CEWde7hJDk1', 'CDn-R0hjf32', 'CD_mUZTjDmF', 'CEV0fH8pqh2', 'CDXig_xjwkc', 'CD54mkCDt68', 'CEVfvMPp17N', 'CC0th3NFEz_', 'CCU5cqijjGS', 'CD0g8ZZDzmI', 'CETvWx9paZk', 'CAmEVaLgDO5', 'CDyrbrcDU2c', 'CDidAN6jUgX', 'CDf0pnnDOJW', 'CETG1a5pCUs', 'CAidJlmgc89', 'B_6bE0oglZg', 'CDQvcJhjZYs', 'CDOsSuVjGPF', 'CB_4zirHkOu', 'CESwMbMpXxU', 'CEA462CpABv', 'B_O3qGGFr2N', 'CDL_tfRjroZ', 'CDLPPWljgej', 'B-Q40rRnVYE', 'B61z1jPCodg', 'B5i50aviYda', 'BxI37HVHD7d', 'CD_YqWXpf7B', 'CD-zmh9Joyu', 'B-4pTcTjE-S', 'B-v9W1KD7Mp', 'B-sCDNDFt0Z', 'CDGNPKaDhvZ', 'BxH10kXlRiV', 'BvwEDRxnDG3', 'BujwEplHX2C', 'Bub9d1yHNkD', 'CD8y4ybJaDF', 'CDz0J-ApDOM', 'CDx01EbpjTj', 'B-lVqqpj2Dz', 'CCslpLzDssV', 'BqpTjrpnjDe', 'CDxfyBppJno', 'B9WuE0qlYPk', 'CCfoTCXDUtM', 'BpNdP4bntAd', 'CDv0GDVpV4x', 'B83Y-zHl5ux', 'CCS1onADFNk', 'BpDFtm1H1sh', 'CDvkXmypbMd', 'B8rA5uHlYsY', 'CCQeKkJDMLk', 'CEhHaqelEiG', 'Bope01LFBu3', 'CDsjqzSpTgG', 'CDqqAswJQhK', 'B8f29fcFFuv', 'CCC3yZ
# ...

# %%
shortcode_df = pd.DataFrame(shortcode, columns = ['shortcode'], index = range(0, 22375))
shortcode_df
# Out:
#          shortcode
# 0      CEasJz1JPgQ
# 1      CEY3iR2pr-l
# 2      CEYOgJUJ1KR
# 3      CEWyKvgJE1C
# 4      CEWde7hJDk1
# ...            ...
# 22370  CDd8XJ4Fm3Y
# 22371  CDd7qDAlaO3
# 22372  CDd7U1IFXCu
# 22373  CDd60iUlSIr
# 22374  CDdjlfqlZEf
#
# [22375 rows x 1 columns]

# %%
word_df.dtypes
# Out:
# insta_id         object
# inner_id          int64
# post_date        object
# url              object
# content          object
# media_url        object
# hashtag          object
# region_tag       object
# like_count        int64
# view_count       object
# crawling_time    object
# team_idx          int64
# next_page        object
# dtype: object

# %%
shortcode_df.dtypes
# Out:
# shortcode    object
# dtype: object

# %%
word_df.to_csv("/content/gdrive/My Drive/프로젝트/word_again/word_df.csv")

# %%
shortcode_df.to_csv("/content/gdrive/My Drive/프로젝트/word_again/shortcode_df.csv")
