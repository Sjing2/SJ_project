# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjing2/SJ_project/blob/master/%5B%EB%A7%88%EC%BC%80%ED%8C%85%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%5D%20%EC%8B%9C%EC%9E%A5%20%EB%B6%84%EC%84%9D%EC%9D%84%20%EC%9C%84%ED%95%9C%20%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%B0%8F%20%EC%BB%A4%EB%AE%A4%EB%8B%88%ED%8B%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D%20%EA%B8%B0%EB%B0%98%20%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8%20%EC%82%AC%EC%9A%A9%EC%9E%90%20%ED%94%84%EB%A1%9C%ED%8C%8C%EC%9D%BC%EB%A7%81/2.%20Preprocessing/10.%5B%EC%A0%84%EC%B2%98%EB%A6%AC%5D%20Post%20Concat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/gdrive/My Drive/프로젝트/word_again/cc_word_add.csv', index_col = [0])

# %%
df
# Out:
#          shortcode  ...                                          next_page
# 0      CEasJz1JPgQ  ...  https://www.instagram.com/graphql/query/?query...
# 1      CEY3iR2pr-l  ...  https://www.instagram.com/graphql/query/?query...
# 2      CEYOgJUJ1KR  ...  https://www.instagram.com/graphql/query/?query...
# 3      CEWyKvgJE1C  ...  https://www.instagram.com/graphql/query/?query...
# 4      CEWde7hJDk1  ...  https://www.instagram.com/graphql/query/?query...
# ...            ...  ...                                                ...
# 22370  CDd8XJ4Fm3Y  ...  https://www.instagram.com/graphql/query/?query...
# 22371  CDd7qDAlaO3  ...  https://www.instagram.com/graphql/query/?query...
# 22372  CDd7U1IFXCu  ...  https://www.instagram.com/graphql/query/?query...
# 22373  CDd60iUlSIr  ...  https://www.instagram.com/graphql/query/?query...
# 22374  CDdjlfqlZEf  ...  https://www.instagram.com/graphql/query/?query...
#
# [22375 rows x 14 columns]

# %%
post_df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Final/cc_post2.csv')

# %%
post_df
# Out:
#          shortcode            insta_id  ...        crawling_time team_idx
# 0      CDoeTIvFOC9  yoonseo_park_flord  ...  2020-09-05 08:25:56        4
# 1      CDjdMIpF4ua  yoonseo_park_flord  ...  2020-09-05 08:25:56        4
# 2      CDjbmy3FHae  yoonseo_park_flord  ...  2020-09-05 08:25:56        4
# 3      CDbOBjYlc8n  yoonseo_park_flord  ...  2020-09-05 08:25:57        4
# 4      B1LWF8jpmZM      romantic2wheel  ...  2020-09-05 08:25:57        4
# ...            ...                 ...  ...                  ...      ...
# 88208  BA6ksSIO7Z7          baboheejin  ...  2020-09-06 07:24:51        4
# 88209  BA32YqrO7R0          baboheejin  ...  2020-09-06 07:24:52        4
# 88210  BA2V74-O7RG          baboheejin  ...  2020-09-06 07:24:52        4
# 88211  BA2M_NBO7d6          baboheejin  ...  2020-09-06 07:24:52        4
# 88212  BA2L55lu7bh          baboheejin  ...  2020-09-06 07:24:52        4
#
# [88213 rows x 13 columns]

# %%
result = pd.concat([df, post_df])
result
# Out:
#          shortcode  ...                                          next_page
# 0      CEasJz1JPgQ  ...  https://www.instagram.com/graphql/query/?query...
# 1      CEY3iR2pr-l  ...  https://www.instagram.com/graphql/query/?query...
# 2      CEYOgJUJ1KR  ...  https://www.instagram.com/graphql/query/?query...
# 3      CEWyKvgJE1C  ...  https://www.instagram.com/graphql/query/?query...
# 4      CEWde7hJDk1  ...  https://www.instagram.com/graphql/query/?query...
# ...            ...  ...                                                ...
# 88208  BA6ksSIO7Z7  ...                                                NaN
# 88209  BA32YqrO7R0  ...                                                NaN
# 88210  BA2V74-O7RG  ...                                                NaN
# 88211  BA2M_NBO7d6  ...                                                NaN
# 88212  BA2L55lu7bh  ...                                                NaN
#
# [110588 rows x 14 columns]

# %%
result.to_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Final/cc_post.csv', index=False)

# %%
result_df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Final/cc_post.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
result_df
# Out:
#           shortcode  ...                                          next_page
# 0       CEasJz1JPgQ  ...  https://www.instagram.com/graphql/query/?query...
# 1       CEY3iR2pr-l  ...  https://www.instagram.com/graphql/query/?query...
# 2       CEYOgJUJ1KR  ...  https://www.instagram.com/graphql/query/?query...
# 3       CEWyKvgJE1C  ...  https://www.instagram.com/graphql/query/?query...
# 4       CEWde7hJDk1  ...  https://www.instagram.com/graphql/query/?query...
# ...             ...  ...                                                ...
# 110583  BA6ksSIO7Z7  ...                                                NaN
# 110584  BA32YqrO7R0  ...                                                NaN
# 110585  BA2V74-O7RG  ...                                                NaN
# 110586  BA2M_NBO7d6  ...                                                NaN
# 110587  BA2L55lu7bh  ...                                                NaN
#
# [110588 rows x 14 columns]
