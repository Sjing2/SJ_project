# %% [markdown]
# ## 크롤링한 의사록 데이터 불러오기(업데이트 날짜, 제목, 내용)

# %%
import re
from datetime import datetime, timedelta
import pandas as pd
import csv
import numpy as np

# %%
bok_minutes = pd.read_csv('word_bok_minutes.csv',index_col=[0], header=None, sep=',')
bok_minutes
# Out:
#                                                        1
# 0
# NaN                                                    0
# 0.0    2020년도 제14차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 1.0    2020년도 제13차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 2.0    2020년도 제12차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 3.0    2020년도 제11차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# ...                                                  ...
# 305.0  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 306.0  金融通貨委員會 議事錄\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 307.0  金融通貨委員會 議事錄\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 308.0  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 309.0  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
#
# [311 rows x 1 columns]

# %%
bok = pd.read_csv('bok_text_date.csv', index_col=[0], header=0, sep=',')
bok.drop(['text'], inplace=True, axis=1)

bok_title = pd.read_csv('bok_title.csv', index_col=[0], header=0, sep=',')
bok['title'] = bok_title

bok['minutes'] = bok_minutes

bok
# Out:
#            date                                 title  \
# 0    2020.07.10  금융통화위원회 의사록(2020년도 제14차)(2020.6.24.)
# 1    2020.06.30  금융통화위원회 의사록(2020년도 제13차)(2020.6.11.)
# 2    2020.06.16  금융통화위원회 의사록(2020년도 제12차)(2020.5.28.)
# 3    2020.06.02  금융통화위원회 의사록(2020년도 제11차)(2020.5.14.)
# 4    2020.05.06   금융통화위원회 의사록(2020년도 제9차)(2020.4.16.)
# ..          ...                                   ...
# 305  2005.11.08   금융통화위원회 의사록(2005년도 제20차)(2005.9.22)
# 306  2005.10.25    금융통화위원회 의사록(2005년도 제19차)(2005.9.8)
# 307  2005.09.27   금융통화위원회 의사록(2005년도 제17차)(2005.8.11)
# 308  2005.08.23    금융통화위원회 의사록(2005년도 제14차)(2005.7.7)
# 309  2005.08.09   금융통화위원회 의사록(2005년도 제13차)(2005.6.23)
#
#                                                minutes
# 0    2020년도 제14차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 1    2020년도 제13차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 2    2020년도 제12차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 3    2020년도 제11차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 4    2020년도 제9차\n\n\n\n\n\n금융통화위원회(임시) 의사록\n\n\n\n\...
# ..                                                 ...
# 305  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 306  金融通貨委員會 議事錄\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 307  金融通貨委員會 議事錄\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 308  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 309  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
#
# [310 rows x 3 columns]

# %% [markdown]
# ### 의사록 제목에서 '회의날짜' 추출(정규표현식 사용)
# 크롤링한 날짜는 의사록 업데이트 날짜, 제목 속 날짜가 회의일

# %%
title_ls = list(bok['title'])
titles=[]
for title in title_ls:
    date = re.findall('(?<=\)\().*\.[0-9]+(?=\.?)', title)
    titles.append(datetime.strptime(("".join(date)), '%Y.%m.%d'))
    
titles
# Out:
# [datetime.datetime(2020, 6, 24, 0, 0),
#  datetime.datetime(2020, 6, 11, 0, 0),
#  datetime.datetime(2020, 5, 28, 0, 0),
#  datetime.datetime(2020, 5, 14, 0, 0),
#  datetime.datetime(2020, 4, 16, 0, 0),
#  datetime.datetime(2020, 4, 9, 0, 0),
#  datetime.datetime(2020, 3, 26, 0, 0),
#  datetime.datetime(2020, 3, 16, 0, 0),
#  datetime.datetime(2020, 3, 12, 0, 0),
#  datetime.datetime(2020, 2, 27, 0, 0),
#  datetime.datetime(2020, 1, 17, 0, 0),
#  datetime.datetime(2019, 12, 26, 0, 0),
#  datetime.datetime(2019, 12, 12, 0, 0),
#  datetime.datetime(2019, 11, 29, 0, 0),
#  datetime.datetime(2019, 10, 16, 0, 0),
#  datetime.datetime(2019, 9, 26, 0, 0),
#  datetime.datetime(2019, 8, 30, 0, 0),
#  datetime.datetime(2019, 8, 8, 0, 0),
#  datetime.datetime(2019, 7, 18, 0, 0),
#  datetime.datetime(2019, 6, 20, 0, 0),
#  datetime.datetime(2019, 5, 31, 0, 0),
#  datetime.datetime(2019, 5, 9, 0, 0),
#  datetime.datetime(2019, 4, 18, 0, 0),
#  datetime.datetime(2019, 3, 28, 0, 0),
#  datetime.datetime(2019, 2, 28, 0, 0),
#  datetime.datetime(2019, 2, 14, 0, 0),
#  datetime.datetime(2019, 1, 24, 0, 0),
#  datetime.datetime(2019, 1, 17, 0, 0),
#  datetime.datetime(2018, 12, 26, 0, 0),
#  datetime.datetime(2018, 12, 20, 0, 0),
#  datetime.datetime(2018, 12, 6, 0, 0),
#  datetime.datetime(2018, 11, 30, 0, 0),
#  datetime.datetime(2018, 11, 8, 0, 0),
#  datetime.datetime(2018, 10, 18, 0, 0),
#  datetime.datetime(2018, 9, 20, 0, 0),
#  datetime.datetime(2018, 8, 31, 0, 0),
#  datetime.datetime(2018, 7, 26, 0, 0),
#  datetime.datetime(2018, 7, 12, 0, 0),
#  datetime.datetime(2018, 6, 20, 0, 0),
#  datetime.datetime(2018, 5, 24, 0, 0),
#  datetime.datetime(2018, 4, 26, 0, 0),
#  datetime.datetime(2018, 4, 12, 0, 0),
#  datetime.datetime(2018, 3, 29, 0, 0),
#  datetime.datetime(2018, 3, 8, 0, 0),
#  datetime.datetime(2018, 2, 27, 0, 0),
#  datetime.datetime(2018, 2, 8, 0, 0),
#  datetime.datetime(2018, 1, 18, 0, 0),
#  datetime.datetime(2017, 12, 28, 0, 0),
#  datetime.datetime(2017, 12, 14, 0, 0),
#  datetime.datetime(2017, 12, 7, 0, 0),
#  datetime.datetime(2017, 11, 30, 0, 0),
#  datetime.datetime(2017, 11, 9, 0, 0),
#  datetime.datetime(2017, 10, 19, 0, 0),
#  datetime.datetime(2017, 9, 21, 0, 0),
#  datetime.datetime(2017, 8, 31, 0, 0),
#  datetime.datetime(2017, 8, 10, 0, 0),
#  datetime.datetime(2017, 7, 13, 0, 0),
#  datetime.datetime(2017, 6, 22, 0, 0),
#  datetime.datetime(2017, 5, 25, 0, 0),
#  datetime.datetime(2017, 4, 27, 0, 0),
#  datetime.datetime(2017, 4, 13, 0, 0),
#  datetime.datetime(2017, 3, 23, 0, 0),
#  datetime.datetime(2017, 2, 23, 0, 0),
#  datetime.datetime(2017, 1, 26, 0, 0),
#  datetime.datetime(2017, 1, 13, 0, 0),
#  datetime.datetime(2016, 12, 29, 0, 0),
#  datetime.datetime(2016, 12, 21, 0, 0),
#  datetime.datetime(2016, 12, 15, 0, 0),
#  datetime.datetime(2016, 11, 24, 0, 0),
#  datetime.datetime(2016, 11, 11, 0, 0),
#  datetime.datetime(2016, 10, 27, 0, 0),
#  datetime.datetime(2016, 10, 13, 0, 0),
#  datetime.datetime(2016, 9, 22, 0, 0),
#  datetime.datetime(2016, 9, 9, 0, 0),
#  datetime.datetime(2016, 8, 11, 0, 0),
#  datetime.datetime(2016, 7, 14, 0, 0),
#  datetime.datetime(2016, 7, 1, 0, 0),
#  datetime.datetime(2016, 6, 23, 0, 0),
#  datetime.datetime(2016, 6, 9, 0, 0),
#  datetime.datetime(2016, 5, 13, 0, 0),
#  datetime.datetime(2016, 4, 19, 0, 0),
#  datetime.datetime(2016, 3, 24, 0, 0),
#  datetime.datetime(2016, 3, 10, 0, 0),
#  datetime.datetime(2016, 2, 25, 0, 0),
#  datetime.datetime(2016, 2, 16, 0, 0),
#  datetime.datetime(2016, 1, 28, 0, 0),
#  datetime.datetime(2016, 1, 14, 0, 0),
#  datetime.datetime(2015, 12, 24, 0, 0),
#  datetime.datetime(2015, 12, 16, 0, 0),
#  datetime.datetime(2015, 12, 10, 0, 0),
#  datetime.datetime(2015, 11, 26, 0, 0),
#  datetime.datetime(2015, 11, 12, 0, 0),
#  datetime.datetime(2015, 10, 29, 0, 0),
#  datetime.datetime(2015, 10, 15, 0, 0),
#  datetime.datetime(2015, 9, 24, 0, 0),
#  datetime.datetime(2015, 9, 11, 0, 0),
#  datetime.datetime(2015, 8, 27, 0, 0),
#  datetime.datetime(2015, 8, 13, 0, 0),
#  datetime.datetime(2015, 7, 23, 0, 0),
#  datetime.datetime(2015, 7, 9, 0, 0),
#  datetime.datetime(2015, 6, 25, 0, 0),
#  datetime.datetime(2015, 6, 11, 0, 0),
#  datetime.datetime(2015, 5, 15, 0, 0),
#  datetime.datetime(2015, 4, 23, 0, 0),
#  datetime.datetime(2015, 4, 9, 0, 0),
#  datetime.datetime(2015, 3, 26, 0, 0),
#  datetime.datetime(2015, 3, 12, 0, 0),
#  datetime.datetime(2015, 2, 17, 0, 0),
#  datetime.datetime(2015, 1, 29, 0, 0),
#  datetime.datetime(2015, 1, 15, 0, 0),
#  datetime.datetime(2014, 12, 24, 0, 0),
#  datetime.datetime(2014, 12, 11, 0, 0),
#  datetime.datetime(2014, 11, 13, 0, 0),
#  datetime.datetime(2014, 10, 23, 0, 0),
#  datetime.datetime(2014, 10, 15, 0, 0),
#  datetime.datetime(2014, 9, 25, 0, 0),
#  datetime.datetime(2014, 9, 12, 0, 0),
#  datetime.datetime(2014, 8, 14, 0, 0),
#  datetime.datetime(2014, 7, 24, 0, 0),
#  datetime.datetime(2014, 7, 10, 0, 0),
#  datetime.datetime(2014, 6, 12, 0, 0),
#  datetime.datetime(2014, 5, 9, 0, 0),
#  datetime.datetime(2014, 4, 24, 0, 0),
#  datetime.datetime(2014, 4, 10, 0, 0),
#  datetime.datetime(2014, 3, 27, 0, 0),
#  datetime.datetime(2014, 3, 13, 0, 0),
#  datetime.datetime(2014, 2, 13, 0, 0),
#  datetime.datetime(2014, 1, 9, 0, 0),
#  datetime.datetime(2013, 12, 26, 0, 0),
#  datetime.datetime(2013, 12, 12, 0, 0),
#  datetime.datetime(2013, 11, 14, 0, 0),
#  datetime.datetime(2013, 10, 24, 0, 0),
#  datetime.datetime(2013, 10, 10, 0, 0),
#  datetime.datetime(2013, 9, 26, 0, 0),
#  datetime.datetime(2013, 9, 12, 0, 0),
#  datetime.datetime(2013, 8, 8, 0, 0),
#  datetime.datetime(2013, 7, 25, 0, 0),
#  datetime.datetime(2013, 7, 11, 0, 0),
#  datetime.datetime(2013, 6, 27, 0, 0),
#  datetime.datetime(2013, 6, 13, 0, 0),
#  datetime.datetime(2013, 5, 9, 0, 0),
#  datetime.datetime(2013, 4, 25, 0, 0),
#  datetime.datetime(2013, 4, 11, 0, 0),
#  datetime.datetime(2013, 3, 28, 0, 0),
#  datetime.datetime(2013, 3, 14, 0, 0),
#  datetime.datetime(2013, 2, 28, 0, 0),
#  datetime.datetime(2013, 2, 14, 0, 0),
#  datetime.datetime(2013, 1, 11, 0, 0),
#  datetime.datetime(2012, 12, 27, 0, 0),
#  datetime.datetime(2012, 12, 13, 0, 0),
#  datetime.datetime(2012, 11, 9, 0, 0),
#  datetime.datetime(2012, 10, 25, 0, 0),
#  datetime.datetime(2012, 10, 11, 0, 0),
#  datetime.datetime(2012, 9, 27, 0, 0),
#  datetime.datetime(2012, 9, 13, 0, 0),
#  datetime.datetime(2012, 8, 9, 0, 0),
#  datetime.datetime(2012, 7, 26, 0, 0),
#  datetime.datetime(2012, 7, 12, 0, 0),
#  datetime.datetime(2012, 6, 21, 0, 0),
#  datetime.datetime(2012, 6, 8, 0, 0),
#  datetime.datetime(2012, 5, 10, 0, 0),
#  datetime.datetime(2012, 4, 13, 0, 0),
#  datetime.datetime(2012, 3, 22, 0, 0),
#  datetime.datetime(2012, 3, 8, 0, 0),
#  datetime.datetime(2012, 2, 9, 0, 0),
#  datetime.datetime(2012, 1, 26, 0, 0),
#  datetime.datetime(2012, 1, 13, 0, 0),
#  datetime.datetime(2011, 12, 29, 0, 0),
#  datetime.datetime(2011, 12, 22, 0, 0),
#  datetime.datetime(2011, 12, 16, 0, 0),
#  datetime.datetime(2011, 12, 8, 0, 0),
#  datetime.datetime(2011, 11, 24, 0, 0),
#  datetime.datetime(2011, 11, 11, 0, 0),
#  datetime.datetime(2011, 10, 13, 0, 0),
#  datetime.datetime(2011, 9, 22, 0, 0),
#  datetime.datetime(2011, 9, 8, 0, 0),
#  datetime.datetime(2011, 8, 11, 0, 0),
#  datetime.datetime(2011, 7, 21, 0, 0),
#  datetime.datetime(2011, 7, 14, 0, 0),
#  datetime.datetime(2011, 6, 23, 0, 0),
#  datetime.datetime(2011, 6, 10, 0, 0),
#  datetime.datetime(2011, 5, 13, 0, 0),
#  datetime.datetime(2011, 4, 12, 0, 0),
#  datetime.datetime(2011, 3, 24, 0, 0),
#  datetime.datetime(2011, 3, 10, 0, 0),
#  datetime.datetime(2011, 2, 24, 0, 0),
#  datetime.datetime(2011, 2, 11, 0, 0),
#  datetime.datetime(2011, 1, 20, 0, 0),
#  datetime.datetime(2011, 1, 13, 0, 0),
#  datetime.datetime(2011, 1, 6, 0, 0),
#  datetime.datetime(2010, 12, 23, 0, 0),
#  datetime.datetime(2010, 12, 9, 0, 0),
#  datetime.datetime(2010, 11, 16, 0, 0),
#  datetime.datetime(2010, 10, 14, 0, 0),
#  datetime.datetime(2010, 9, 24, 0, 0),
#  datetime.datetime(2010, 9, 9, 0, 0),
#  datetime.datetime(2010, 8, 31, 0, 0),
#  datetime.datetime(2010, 8, 12, 0, 0),
#  datetime.datetime(2010, 7, 29, 0, 0),
#  datetime.datetime(2010, 7, 9, 0, 0),
#  datetime.datetime(2010, 6, 24, 0, 0),
#  datetime.datetime(2010, 6, 10, 0, 0),
#  datetime.datetime(2010, 5, 12, 0, 0),
#  datetime.datetime(2010, 4, 22, 0, 0),
#  datetime.datetime(2010, 4, 9, 0, 0),
#  datetime.datetime(2010, 3, 25, 0, 0),
#  datetime.datetime(2010, 3, 11, 0, 0),
#  datetime.datetime(2010, 2, 11, 0, 0),
#  datetime.datetime(2010, 1, 21, 0, 0),
#  datetime.datetime(2010, 1, 7, 0, 0),
#  datetime.datetime(2010, 1, 8, 0, 0),
#  datetime.datetime(2009, 12, 24, 0, 0),
#  datetime.datetime(2009, 12, 10, 0, 0),
#  datetime.datetime(2009, 11, 26, 0, 0),
#  datetime.datetime(2009, 11, 12, 0, 0),
#  datetime.datetime(2009, 10, 9, 0, 0),
#  datetime.datetime(2009, 9, 24, 0, 0),
#  datetime.datetime(2009, 9, 10, 0, 0),
#  datetime.datetime(2009, 8, 11, 0, 0),
#  datetime.datetime(2009, 7, 23, 0, 0),
#  datetime.datetime(2009, 7, 9, 0, 0),
#  datetime.datetime(2009, 6, 25, 0, 0),
#  datetime.datetime(2009, 6, 11, 0, 0),
#  datetime.datetime(2009, 5, 21, 0, 0),
#  datetime.datetime(2009, 5, 12, 0, 0),
#  datetime.datetime(2009, 4, 30, 0, 0),
#  datetime.datetime(2009, 4, 23, 0, 0),
#  datetime.datetime(2009, 4, 9, 0, 0),
#  datetime.datetime(2009, 3, 26, 0, 0),
#  datetime.datetime(2009, 3, 12, 0, 0),
#  datetime.datetime(2009, 2, 25, 0, 0),
#  datetime.datetime(2009, 2, 12, 0, 0),
#  datetime.datetime(2009, 1, 22, 0, 0),
#  datetime.datetime(2009, 1, 9, 0, 0),
#  datetime.datetime(2009, 1, 2, 0, 0),
#  datetime.datetime(2008, 12, 24, 0, 0),
#  datetime.datetime(2008, 12, 11, 0, 0),
#  datetime.datetime(2008, 12, 3, 0, 0),
#  datetime.datetime(2008, 11, 7, 0, 0),
#  datetime.datetime(2008, 10, 23, 0, 0),
#  datetime.datetime(2008, 10, 27, 0, 0),
#  datetime.datetime(2008, 10, 9, 0, 0),
#  datetime.datetime(2008, 9, 25, 0, 0),
#  datetime.datetime(2008, 9, 11, 0, 0),
#  datetime.datetime(2008, 8, 7, 0, 0),
#  datetime.datetime(2008, 7, 24, 0, 0),
#  datetime.datetime(2008, 7, 10, 0, 0),
#  datetime.datetime(2008, 6, 26, 0, 0),
#  datetime.datetime(2008, 6, 12, 0, 0),
#  datetime.datetime(2008, 5, 22, 0, 0),
#  datetime.datetime(2008, 5, 8, 0, 0),
#  datetime.datetime(2008, 4, 10, 0, 0),
#  datetime.datetime(2008, 3, 20, 0, 0),
#  datetime.datetime(2008, 3, 7, 0, 0),
#  datetime.datetime(2008, 2, 13, 0, 0),
#  datetime.datetime(2008, 1, 24, 0, 0),
#  datetime.datetime(2008, 1, 10, 0, 0),
#  datetime.datetime(2008, 1, 4, 0, 0),
#  datetime.datetime(2007, 12, 20, 0, 0),
#  datetime.datetime(2007, 12, 7, 0, 0),
#  datetime.datetime(2007, 11, 22, 0, 0),
#  datetime.datetime(2007, 11, 8, 0, 0),
#  datetime.datetime(2007, 10, 11, 0, 0),
#  datetime.datetime(2007, 9, 20, 0, 0),
#  datetime.datetime(2007, 9, 7, 0, 0),
#  datetime.datetime(2007, 8, 9, 0, 0),
#  datetime.datetime(2007, 7, 26, 0, 0),
#  datetime.datetime(2007, 7, 12, 0, 0),
#  datetime.datetime(2007, 6, 21, 0, 0),
#  datetime.datetime(2007, 6, 8, 0, 0),
#  datetime.datetime(2007, 5, 10, 0, 0),
#  datetime.datetime(2007, 4, 12, 0, 0),
#  datetime.datetime(2007, 3, 22, 0, 0),
#  datetime.datetime(2007, 3, 8, 0, 0),
#  datetime.datetime(2007, 2, 8, 0, 0),
#  datetime.datetime(2007, 1, 25, 0, 0),
#  datetime.datetime(2007, 1, 11, 0, 0),
#  datetime.datetime(2007, 1, 5, 0, 0),
#  datetime.datetime(2006, 12, 21, 0, 0),
#  datetime.datetime(2006, 12, 7, 0, 0),
#  datetime.datetime(2006, 11, 23, 0, 0),
#  datetime.datetime(2006, 11, 9, 0, 0),
#  datetime.datetime(2006, 10, 26, 0, 0),
#  datetime.datetime(2006, 10, 12, 0, 0),
#  datetime.datetime(2006, 9, 21, 0, 0),
#  datetime.datetime(2006, 9, 7, 0, 0),
#  datetime.datetime(2006, 8, 24, 0, 0),
#  datetime.datetime(2006, 8, 17, 0, 0),
#  datetime.datetime(2006, 8, 10, 0, 0),
#  datetime.datetime(2006, 7, 7, 0, 0),
#  datetime.datetime(2006, 6, 22, 0, 0),
#  datetime.datetime(2006, 6, 8, 0, 0),
#  datetime.datetime(2006, 5, 25, 0, 0),
#  datetime.datetime(2006, 5, 11, 0, 0),
#  datetime.datetime(2006, 4, 7, 0, 0),
#  datetime.datetime(2006, 3, 23, 0, 0),
#  datetime.datetime(2006, 3, 9, 0, 0),
#  datetime.datetime(2006, 2, 9, 0, 0),
#  datetime.datetime(2006, 1, 26, 0, 0),
#  datetime.datetime(2006, 1, 12, 0, 0),
#  datetime.datetime(2006, 1, 5, 0, 0),
#  datetime.datetime(2005, 12, 22, 0, 0),
#  datetime.datetime(2005, 12, 8, 0, 0),
#  datetime.datetime(2005, 11, 10, 0, 0),
#  datetime.datetime(2005, 10, 11, 0, 0),
#  datetime.datetime(2005, 9, 22, 0, 0),
#  datetime.datetime(2005, 9, 8, 0, 0),
#  datetime.datetime(2005, 8, 11, 0, 0),
#  datetime.datetime(2005, 7, 7, 0, 0),
#  datetime.datetime(2005, 6, 23, 0, 0)]

# %%
bok['title'] = titles

# %%
bok.columns = ['update_text', 'new_date','minutes']
bok
# Out:
#     update_text   new_date                                            minutes
# 0    2020.07.10 2020-06-24  2020년도 제14차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 1    2020.06.30 2020-06-11  2020년도 제13차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 2    2020.06.16 2020-05-28  2020년도 제12차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 3    2020.06.02 2020-05-14  2020년도 제11차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 4    2020.05.06 2020-04-16  2020년도 제9차\n\n\n\n\n\n금융통화위원회(임시) 의사록\n\n\n\n\...
# ..          ...        ...                                                ...
# 305  2005.11.08 2005-09-22  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 306  2005.10.25 2005-09-08  金融通貨委員會 議事錄\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 307  2005.09.27 2005-08-11  金融通貨委員會 議事錄\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 308  2005.08.23 2005-07-07  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 309  2005.08.09 2005-06-23  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
#
# [310 rows x 3 columns]

# %%
#오래된 것-> 최신 순으로 순서변경
bok = bok[::-1]
bok.index = [i for i in range(310)]
bok
# Out:
#     update_text   new_date                                            minutes
# 0    2005.08.09 2005-06-23  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 1    2005.08.23 2005-07-07  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 2    2005.09.27 2005-08-11  金融通貨委員會 議事錄\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 3    2005.10.25 2005-09-08  金融通貨委員會 議事錄\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 4    2005.11.08 2005-09-22  金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# ..          ...        ...                                                ...
# 305  2020.05.06 2020-04-16  2020년도 제9차\n\n\n\n\n\n금융통화위원회(임시) 의사록\n\n\n\n\...
# 306  2020.06.02 2020-05-14  2020년도 제11차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 307  2020.06.16 2020-05-28  2020년도 제12차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 308  2020.06.30 2020-06-11  2020년도 제13차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
# 309  2020.07.10 2020-06-24  2020년도 제14차\n\n\n\n\n\n금융통화위원회(정기) 의사록\n\n\n\n...
#
# [310 rows x 3 columns]

# %% [markdown]
# ## 제공된 섹션분리 함수 사용하여 의사록 전처리

# %%
import os
import sys
import platform
import pandas as pd
import re
from datetime import datetime, timedelta
import csv

# %%
#문장단위 토큰화
def tidy_sentences(section):
    sentence_enders = re.compile(r'((?<=[함음됨임봄짐움])(\s*\n|\.|;)|(?<=다)\.)\s*')
    splits = list((m.start(), m.end()) for m in re.finditer(sentence_enders, section))
    starts = [0] + [i[1] for i in splits]
    ends = [i[0] for i in splits]
    sentences = [section[start:end] for start, end in zip(starts[:-1], ends)]
    for i, s in enumerate(sentences):
        sentences[i] = (s.replace('\n', ' ').replace(' ', ' ')) + '.'

    text = '\n'.join(sentences) if len(sentences) > 0 else ''
    return sentences, text

# %%
#섹션 나누는 규칙 정하기
import re 

def preprocess_minutes(minutes):

    pos = re.search('(.?국내외\s?경제\s?동향.?과 관련하여,?|\(가\).+경제전망.*|\(가\) 국내외 경제동향 및 평가)\n?\s*일부 위원은', minutes, re.MULTILINE)
    s1 = pos.start() if pos else -1
    
    pos = re.search('(.?외환.?국제금융\s?동향.?과 관련하여.*|\(나\) 외환.국제금융\s?(및 금융시장)?\s?동향)\n?\s*(일부 위원은|대부분의 위원들은)', minutes,re.MULTILINE)
    s2 = pos.start() if pos else -1
    
    pos = re.search('(.?금융시장\s?동향.?과 관련하여,?|\(다\) 금융시장\s?동향)\n?\s*일부 위원은', minutes, re.MULTILINE)
    s3 = pos.start() if pos else -1
    
    pos = re.search('((\((다|라)\) )?.?통화정책\s?방향.?에 관한 토론,?|이상과 같은 의견\s?교환을 바탕으로.*통화정책\s?방향.*에.*토론.*)\n?', minutes,re.MULTILINE)
    s4 = pos.start() if pos else -1
    
    pos = re.search('(\(4\) 정부측 열석자 발언.*)\n?', minutes, re.MULTILINE)
    s5 = pos.start() if pos else -1
    
    pos = re.search('(\(.*\) 한국은행 기준금리 결정에 관한 위원별 의견\s?개진|이상과 같은 토론에 이어 .* 관한 위원별 의견개진이 있었음.*)\n?', minutes,re.MULTILINE)
    s6 = pos.start() if pos else -1
    
    positer = re.finditer('(\(\s?.*\s?\) ()(심의결과|토의결론))\n?', minutes, re.MULTILINE)
    s7 = [pos.start() for pos in positer if pos.start() > s6]
    s7 = s7[0] if s7 else -1

    # 국내외 경제동향
    bos = s1
    eos = s2
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section1, section1_txt = tidy_sentences(section)

    # 외환․국제금융 동향
    bos = s2
    eos = s3 if s3 >= 0 else s4
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section2, section2_txt = tidy_sentences(section)
    #print(section)

    # 금융시장 동향
    bos = s3
    eos = s4
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section3, section3_txt = tidy_sentences(section)

    # 통화정책방향
    bos = s4
    eos = s5 if s5 >= 0 else s6 if s6 >= 0 else s7
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section4, section4_txt = tidy_sentences(section)

    # 위원별 의견 개진
    bos = s6
    eos = s7
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section5, section5_txt = tidy_sentences(section)

    # 정부측 열석자 발언
    bos = s5
    eos = s6
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('정부측 열석자 발언', section, re.MULTILINE)
    bos = pos.end() + 1 if pos else -1
    section = section[bos:] if bos >= 0 else section
    section6, section6_txt = tidy_sentences(section)

    sections = ['Economic Situation', 'Foreign Currency', 'Financial Markets',
                'Monetary Policy', 'Participants’ Views', 'Government’s View']
    section_texts = (section1, section2, section3, section4, section5, section6)


    return sections, section_texts

# %%
#eKNLPy에서 엔그레마이즈 패키지 사용
import pandas as pd
from ekonlpy.sentiment import MPCK

def text2ngram(text) :
    mpck = MPCK()
    tokens = mpck.tokenize(text)
    ngrams = mpck.ngramize(tokens)
                
    return tokens+ ngrams

# %%
bok_text = bok['minutes']
bok_date = bok['new_date']

# %%
#정해진 규칙에 따라 섹션분리, 섹션 2와 3 부분에서만 ngram추출/ 2005년부터 2020년까지의 의사록에서 모두 추출

import csv
import pandas as pd
from os import listdir
from os.path import isfile, join


    
def preprocessing(source_folder="./", output_file="bok_minutes_2005_2020.csv") :
    df = pd.DataFrame(columns=['date', 'minutes'])
    df["Economic Situation"] = ""
    df["Foreign Currency"] = ""
    df["Financial Markets"] = ""
    df["Monetary Policy"] = ""
    df["Participant Views"] = ""
    df["Government View"] = ""

    df["Economic Situation count"] = ""
    df["Foreign Currency count"] = ""
    df["Financial Markets count"] = ""
    df["Monetary Policy count"] = ""
    df["Participant Views count"] = ""
    df["Government View count"] = ""

    df["ngram"] = ""
    

    for idx, bok in enumerate(bok_text) :
        sections, section_texts = preprocess_minutes(bok)

        print(bok_date[idx])

        try:
            ngrams = []
            for section_text in section_texts[1:3] :
                for sentence in section_text :
                    ngrams.append(','.join(text2ngram(sentence)))

            #print('@@@'.join(ngrams))
            #break

            df.loc[len(df)] = [bok_date[idx],
                               bok_text,
                               '@@@'.join(section_texts[0]),
                               '@@@'.join(section_texts[1]),
                               '@@@'.join(section_texts[2]),
                               '@@@'.join(section_texts[3]),
                               '@@@'.join(section_texts[4]),
                               '@@@'.join(section_texts[5]),
                               len(section_texts[0]),
                               len(section_texts[1]),
                               len(section_texts[2]),
                               len(section_texts[3]),
                               len(section_texts[4]),
                               len(section_texts[5]),
                               '@@@'.join(ngrams)]
        except:
            print("error")

        df.to_csv("bok_minutes_2005_2020.csv", index=False)

        print(df.shape)
preprocessing()
# Out:
# 2005-06-23 00:00:00
# (1, 15)
# 2005-07-07 00:00:00
# (2, 15)
# 2005-08-11 00:00:00
# (3, 15)
# 2005-09-08 00:00:00
# (4, 15)
# 2005-09-22 00:00:00
# (5, 15)
# 2005-10-11 00:00:00
# (6, 15)
# 2005-11-10 00:00:00
# (7, 15)
# 2005-12-08 00:00:00
# (8, 15)
# 2005-12-22 00:00:00
# (9, 15)
# 2006-01-05 00:00:00
# (10, 15)
# 2006-01-12 00:00:00
# (11, 15)
# 2006-01-26 00:00:00
# (12, 15)
# 2006-02-09 00:00:00
# (13, 15)
# 2006-03-09 00:00:00
# (14, 15)
# 2006-03-23 00:00:00
# (15, 15)
# 2006-04-07 00:00:00
# (16, 15)
# 2006-05-11 00:00:00
# (17, 15)
# 2006-05-25 00:00:00
# (18, 15)
# 2006-06-08 00:00:00
# (19, 15)
# 2006-06-22 00:00:00
# (20, 15)
# 2006-07-07 00:00:00
# (21, 15)
# 2006-08-10 00:00:00
# (22, 15)
# 2006-08-17 00:00:00
# (23, 15)
# 2006-08-24 00:00:00
# (24, 15)
# 2006-09-07 00:00:00
# (25, 15)
# 2006-09-21 00:00:00
# (26, 15)
# 2006-10-12 00:00:00
# (27, 15)
# 2006-10-26 00:00:00
# (28, 15)
# 2006-11-09 00:00:00
# (29, 15)
# 2006-11-23 00:00:00
# (30, 15)
# 2006-12-07 00:00:00
# (31, 15)
# 2006-12-21 00:00:00
# (32, 15)
# 2007-01-05 00:00:00
# (33, 15)
# 2007-01-11 00:00:00
# (34, 15)
# 2007-01-25 00:00:00
# (35, 15)
# 2007-02-08 00:00:00
# (36, 15)
# 2007-03-08 00:00:00
# (37, 15)
# 2007-03-22 00:00:00
# (38, 15)
# 2007-04-12 00:00:00
# (39, 15)
# 2007-05-10 00:00:00
# (40, 15)
# 2007-06-08 00:00:00
# (41, 15)
# 2007-06-21 00:00:00
# (42, 15)
# 2007-07-12 00:00:00
# (43, 15)
# 2007-07-26 00:00:00
# (44, 15)
# 2007-08-09 00:00:00
# (45, 15)
# 2007-09-07 00:00:00
# (46, 15)
# 2007-09-20 00:00:00
# (47, 15)
# 2007-10-11 00:00:00
# (48, 15)
# 2007-11-08 00:00:00
# (49, 15)
# 2007-11-22 00:00:00
# (50, 15)
# 2007-12-07 00:00:00
# (51, 15)
# 2007-12-20 00:00:00
# (52, 15)
# 2008-01-04 00:00:00
# (53, 15)
# 2008-01-10 00:00:00
# (54, 15)
# 2008-01-24 00:00:00
# (55, 15)
# 2008-02-13 00:00:00
# (56, 15)
# 2008-03-07 00:00:00
# (57, 15)
# 2008-03-20 00:00:00
# (58, 15)
# 2008-04-10 00:00:00
# (59, 15)
# 2008-05-08 00:00:00
# (60, 15)
# 2008-05-22 00:00:00
# (61, 15)
# 2008-06-12 00:00:00
# (62, 15)
# 2008-06-26 00:00:00
# (63, 15)
# 2008-07-10 00:00:00
# (64, 15)
# 2008-07-24 00:00:00
# (65, 15)
# 2008-08-07 00:00:00
# (66, 15)
# 2008-09-11 00:00:00
# (67, 15)
# 2008-09-25 00:00:00
# (68, 15)
# 2008-10-09 00:00:00
# (69, 15)
# 2008-10-27 00:00:00
# (70, 15)
# 2008-10-23 00:00:00
# (71, 15)
# 2008-11-07 00:00:00
# (72, 15)
# 2008-12-03 00:00:00
# (73, 15)
# 2008-12-11 00:00:00
# (74, 15)
# 2008-12-24 00:00:00
# (75, 15)
# 2009-01-02 00:00:00
# (76, 15)
# 2009-01-09 00:00:00
# (77, 15)
# 2009-01-22 00:00:00
# (78, 15)
# 2009-02-12 00:00:00
# (79, 15)
# 2009-02-25 00:00:00
# (80, 15)
# 2009-03-12 00:00:00
# (81, 15)
# 2009-03-26 00:00:00
# (82, 15)
# 2009-04-09 00:00:00
# (83, 15)
# 2009-04-23 00:00:00
# (84, 15)
# 2009-04-30 00:00:00
# (85, 15)
# 2009-05-12 00:00:00
# (86, 15)
# 2009-05-21 00:00:00
# (87, 15)
# 2009-06-11 00:00:00
# (88, 15)
# 2009-06-25 00:00:00
# (89, 15)
# 2009-07-09 00:00:00
# (90, 15)
# 2009-07-23 00:00:00
# (91, 15)
# 2009-08-11 00:00:00
# (92, 15)
# 2009-09-10 00:00:00
# (93, 15)
# 2009-09-24 00:00:00
# (94, 15)
# 2009-10-09 00:00:00
# (95, 15)
# 2009-11-12 00:00:00
# (96, 15)
# 2009-11-26 00:00:00
# (97, 15)
# 2009-12-10 00:00:00
# (98, 15)
# 2009-12-24 00:00:00
# (99, 15)
# 2010-01-08 00:00:00
# (100, 15)
# 2010-01-07 00:00:00
# (101, 15)
# 2010-01-21 00:00:00
# (102, 15)
# 2010-02-11 00:00:00
# (103, 15)
# 2010-03-11 00:00:00
# (104, 15)
# 2010-03-25 00:00:00
# (105, 15)
# 2010-04-09 00:00:00
# (106, 15)
# 2010-04-22 00:00:00
# (107, 15)
# 2010-05-12 00:00:00
# (108, 15)
# 2010-06-10 00:00:00
# (109, 15)
# 2010-06-24 00:00:00
# (110, 15)
# 2010-07-09 00:00:00
# (111, 15)
# 2010-07-29 00:00:00
# (112, 15)
# 2010-08-12 00:00:00
# (113, 15)
# 2010-08-31 00:00:00
# (114, 15)
# 2010-09-09 00:00:00
# (115, 15)
# 2010-09-24 00:00:00
# (116, 15)
# 2010-10-14 00:00:00
# (117, 15)
# 2010-11-16 00:00:00
# (118, 15)
# 2010-12-09 00:00:00
# (119, 15)
# 2010-12-23 00:00:00
# (120, 15)
# 2011-01-06 00:00:00
# (121, 15)
# 2011-01-13 00:00:00
# (122, 15)
# 2011-01-20 00:00:00
# (123, 15)
# 2011-02-11 00:00:00
# (124, 15)
# 2011-02-24 00:00:00
# (125, 15)
# 2011-03-10 00:00:00
# (126, 15)
# 2011-03-24 00:00:00
# (127, 15)
# 2011-04-12 00:00:00
# (128, 15)
# 2011-05-13 00:00:00
# (129, 15)
# 2011-06-10 00:00:00
# (130, 15)
# 2011-06-23 00:00:00
# (131, 15)
# 2011-07-14 00:00:00
# (132, 15)
# 2011-07-21 00:00:00
# (133, 15)
# 2011-08-11 00:00:00
# (134, 15)
# 2011-09-08 00:00:00
# (135, 15)
# 2011-09-22 00:00:00
# (136, 15)
# 2011-10-13 00:00:00
# (137, 15)
# 2011-11-11 00:00:00
# (138, 15)
# 2011-11-24 00:00:00
# (139, 15)
# 2011-12-08 00:00:00
# (140, 15)
# 2011-12-16 00:00:00
# (141, 15)
# 2011-12-22 00:00:00
# (142, 15)
# 2011-12-29 00:00:00
# (143, 15)
# 2012-01-13 00:00:00
# (144, 15)
# 2012-01-26 00:00:00
# (145, 15)
# 2012-02-09 00:00:00
# (146, 15)
# 2012-03-08 00:00:00
# (147, 15)
# 2012-03-22 00:00:00
# (148, 15)
# 2012-04-13 00:00:00
# (149, 15)
# 2012-05-10 00:00:00
# (150, 15)
# 2012-06-08 00:00:00
# (151, 15)
# 2012-06-21 00:00:00
# (152, 15)
# 2012-07-12 00:00:00
# (153, 15)
# 2012-07-26 00:00:00
# (154, 15)
# 2012-08-09 00:00:00
# (155, 15)
# 2012-09-13 00:00:00
# (156, 15)
# 2012-09-27 00:00:00
# (157, 15)
# 2012-10-11 00:00:00
# (158, 15)
# 2012-10-25 00:00:00
# (159, 15)
# 2012-11-09 00:00:00
# (160, 15)
# 2012-12-13 00:00:00
# (161, 15)
# 2012-12-27 00:00:00
# (162, 15)
# 2013-01-11 00:00:00
# (163, 15)
# 2013-02-14 00:00:00
# (164, 15)
# 2013-02-28 00:00:00
# (165, 15)
# 2013-03-14 00:00:00
# (166, 15)
# 2013-03-28 00:00:00
# (167, 15)
# 2013-04-11 00:00:00
# (168, 15)
# 2013-04-25 00:00:00
# (169, 15)
# 2013-05-09 00:00:00
# (170, 15)
# 2013-06-13 00:00:00
# (171, 15)
# 2013-06-27 00:00:00
# (172, 15)
# 2013-07-11 00:00:00
# (173, 15)
# 2013-07-25 00:00:00
# (174, 15)
# 2013-08-08 00:00:00
# (175, 15)
# 2013-09-12 00:00:00
# (176, 15)
# 2013-09-26 00:00:00
# (177, 15)
# 2013-10-10 00:00:00
# (178, 15)
# 2013-10-24 00:00:00
# (179, 15)
# 2013-11-14 00:00:00
# (180, 15)
# 2013-12-12 00:00:00
# (181, 15)
# 2013-12-26 00:00:00
# (182, 15)
# 2014-01-09 00:00:00
# (183, 15)
# 2014-02-13 00:00:00
# (184, 15)
# 2014-03-13 00:00:00
# (185, 15)
# 2014-03-27 00:00:00
# (186, 15)
# 2014-04-10 00:00:00
# (187, 15)
# 2014-04-24 00:00:00
# (188, 15)
# 2014-05-09 00:00:00
# (189, 15)
# 2014-06-12 00:00:00
# (190, 15)
# 2014-07-10 00:00:00
# (191, 15)
# 2014-07-24 00:00:00
# (192, 15)
# 2014-08-14 00:00:00
# (193, 15)
# 2014-09-12 00:00:00
# (194, 15)
# 2014-09-25 00:00:00
# (195, 15)
# 2014-10-15 00:00:00
# (196, 15)
# 2014-10-23 00:00:00
# (197, 15)
# 2014-11-13 00:00:00
# (198, 15)
# 2014-12-11 00:00:00
# (199, 15)
# 2014-12-24 00:00:00
# (200, 15)
# 2015-01-15 00:00:00
# (201, 15)
# 2015-01-29 00:00:00
# (202, 15)
# 2015-02-17 00:00:00
# (203, 15)
# 2015-03-12 00:00:00
# (204, 15)
# 2015-03-26 00:00:00
# (205, 15)
# 2015-04-09 00:00:00
# (206, 15)
# 2015-04-23 00:00:00
# (207, 15)
# 2015-05-15 00:00:00
# (208, 15)
# 2015-06-11 00:00:00
# (209, 15)
# 2015-06-25 00:00:00
# (210, 15)
# 2015-07-09 00:00:00
# (211, 15)
# 2015-07-23 00:00:00
# (212, 15)
# 2015-08-13 00:00:00
# (213, 15)
# 2015-08-27 00:00:00
# (214, 15)
# 2015-09-11 00:00:00
# (215, 15)
# 2015-09-24 00:00:00
# (216, 15)
# 2015-10-15 00:00:00
# (217, 15)
# 2015-10-29 00:00:00
# (218, 15)
# 2015-11-12 00:00:00
# (219, 15)
# 2015-11-26 00:00:00
# (220, 15)
# 2015-12-10 00:00:00
# (221, 15)
# 2015-12-16 00:00:00
# (222, 15)
# 2015-12-24 00:00:00
# (223, 15)
# 2016-01-14 00:00:00
# (224, 15)
# 2016-01-28 00:00:00
# (225, 15)
# 2016-02-16 00:00:00
# (226, 15)
# 2016-02-25 00:00:00
# (227, 15)
# 2016-03-10 00:00:00
# (228, 15)
# 2016-03-24 00:00:00
# (229, 15)
# 2016-04-19 00:00:00
# (230, 15)
# 2016-05-13 00:00:00
# (231, 15)
# 2016-06-09 00:00:00
# (232, 15)
# 2016-06-23 00:00:00
# (233, 15)
# 2016-07-01 00:00:00
# (234, 15)
# 2016-07-14 00:00:00
# (235, 15)
# 2016-08-11 00:00:00
# (236, 15)
# 2016-09-09 00:00:00
# (237, 15)
# 2016-09-22 00:00:00
# (238, 15)
# 2016-10-13 00:00:00
# (239, 15)
# 2016-10-27 00:00:00
# (240, 15)
# 2016-11-11 00:00:00
# (241, 15)
# 2016-11-24 00:00:00
# (242, 15)
# 2016-12-15 00:00:00
# (243, 15)
# 2016-12-21 00:00:00
# (244, 15)
# 2016-12-29 00:00:00
# (245, 15)
# 2017-01-13 00:00:00
# (246, 15)
# 2017-01-26 00:00:00
# (247, 15)
# 2017-02-23 00:00:00
# (248, 15)
# 2017-03-23 00:00:00
# (249, 15)
# 2017-04-13 00:00:00
# (250, 15)
# 2017-04-27 00:00:00
# (251, 15)
# 2017-05-25 00:00:00
# (252, 15)
# 2017-06-22 00:00:00
# (253, 15)
# 2017-07-13 00:00:00
# (254, 15)
# 2017-08-10 00:00:00
# (255, 15)
# 2017-08-31 00:00:00
# (256, 15)
# 2017-09-21 00:00:00
# (257, 15)
# 2017-10-19 00:00:00
# (258, 15)
# 2017-11-09 00:00:00
# (259, 15)
# 2017-11-30 00:00:00
# (260, 15)
# 2017-12-07 00:00:00
# (261, 15)
# 2017-12-14 00:00:00
# (262, 15)
# 2017-12-28 00:00:00
# (263, 15)
# 2018-01-18 00:00:00
# (264, 15)
# 2018-02-08 00:00:00
# (265, 15)
# 2018-02-27 00:00:00
# (266, 15)
# 2018-03-08 00:00:00
# (267, 15)
# 2018-03-29 00:00:00
# (268, 15)
# 2018-04-12 00:00:00
# (269, 15)
# 2018-04-26 00:00:00
# (270, 15)
# 2018-05-24 00:00:00
# (271, 15)
# 2018-06-20 00:00:00
# (272, 15)
# 2018-07-12 00:00:00
# (273, 15)
# 2018-07-26 00:00:00
# (274, 15)
# 2018-08-31 00:00:00
# (275, 15)
# 2018-09-20 00:00:00
# (276, 15)
# 2018-10-18 00:00:00
# (277, 15)
# 2018-11-08 00:00:00
# (278, 15)
# 2018-11-30 00:00:00
# (279, 15)
# 2018-12-06 00:00:00
# (280, 15)
# 2018-12-20 00:00:00
# (281, 15)
# 2018-12-26 00:00:00
# (282, 15)
# 2019-01-17 00:00:00
# (283, 15)
# 2019-01-24 00:00:00
# (284, 15)
# 2019-02-14 00:00:00
# (285, 15)
# 2019-02-28 00:00:00
# (286, 15)
# 2019-03-28 00:00:00
# (287, 15)
# 2019-04-18 00:00:00
# (288, 15)
# 2019-05-09 00:00:00
# (289, 15)
# 2019-05-31 00:00:00
# (290, 15)
# 2019-06-20 00:00:00
# (291, 15)
# 2019-07-18 00:00:00
# (292, 15)
# 2019-08-08 00:00:00
# (293, 15)
# 2019-08-30 00:00:00
# (294, 15)
# 2019-09-26 00:00:00
# (295, 15)
# 2019-10-16 00:00:00
# (296, 15)
# 2019-11-29 00:00:00
# (297, 15)
# 2019-12-12 00:00:00
# (298, 15)
# 2019-12-26 00:00:00
# (299, 15)
# 2020-01-17 00:00:00
# (300, 15)
# 2020-02-27 00:00:00
# (301, 15)
# 2020-03-12 00:00:00
# (302, 15)
# 2020-03-16 00:00:00
# (303, 15)
# 2020-03-26 00:00:00
# (304, 15)
# 2020-04-09 00:00:00
# (305, 15)
# 2020-04-16 00:00:00
# (306, 15)
# 2020-05-14 00:00:00
# (307, 15)
# 2020-05-28 00:00:00
# (308, 15)
# 2020-06-11 00:00:00
# (309, 15)
# 2020-06-24 00:00:00
# (310, 15)

# %%
tmp = pd.read_csv("bok_minutes_2005_2020.csv", header=0, sep=',')
tmp
# Out:
#            date                                            minutes  \
# 0    2005-06-23  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 1    2005-07-07  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 2    2005-08-11  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 3    2005-09-08  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 4    2005-09-22  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# ..          ...                                                ...
# 305  2020-04-16  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 306  2020-05-14  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 307  2020-05-28  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 308  2020-06-11  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 309  2020-06-24  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
#
#                                     Economic Situation  \
# 0                                                  NaN
# 1    일부 위원은 최근 이란의 새 대통령 취임 이후 자국경제 보호주의 강화 등으로 중동산...
# 2    일부 위원은 소비, 수출, 건설투자가 견조한 증가세를 보이고 물가도 안정세를 이어가...
# 3    일부 위원은 7월 전망시보다 높은 수준을 지속하고 있는 국제유가가 내년도 경제성장률...
# 4                                                  NaN
# ..                                                 ...
# 305                                                NaN
# 306                                                NaN
# 307  일부 위원은 코로나19 사태의 전개양상을 둘러싼 불확실성이 매우 높은 상황에서 관련...
# 308                                                NaN
# 309                                                NaN
#
#                                       Foreign Currency  \
# 0                                                  NaN
# 1    일부 위원은 6월 들어 국제유가가 크게 오르고 원화와 엔화간 동조화 현상이 뚜렷해지...
# 2    일부 위원은 위안화 절상 이후 아시아 통화중 우리나라 원화의 절상폭이 가장 컸다면서...
# 3    일부 위원은 최근 인도네시아 금융불안 사태가 발생한 가운데 국제 환투기세력이 인도네...
# 4                                                  NaN
# ..                                                 ...
# 305                                                NaN
# 306                                                NaN
# 307  일부 위원은 코로나19 사태 이전 풍부한 유동성에 힘입어 미 증시가 사상 최고치를 ...
# 308                                                NaN
# 309                                                NaN
#
#                                      Financial Markets  \
# 0                                                  NaN
# 1    일부 위원은 단기적으로 대출이 급격히 증가한 후에는 반드시 조정이 이어지고 민간소비...
# 2    일부 위원은 최근 장기시장금리 상승에도 불구하고 기업 자금조달은 오히려 확대되고 있...
# 3    일부 위원은 시장이 제대로 작동한다면 비우량등급의 회사채 가산금리가 사상 최저치를 ...
# 4                                                  NaN
# ..                                                 ...
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
#
#                                        Monetary Policy  \
# 0                                                  NaN
# 1    일부 위원은 금년 상반기중 아파트가격 급등세는 전국적인 현상은 아닌 것으로 보인다며...
# 2    일부 위원은 겉으로 보기에 경제성장이 양호할지라도 교역조건 악화로 소득이 저하되는 ...
# 3    일부 위원은 지난 6년간 정책금리가 중립수준의 금리나 준칙금리보다 낮은 수준을 지속...
# 4                                                  NaN
# ..                                                 ...
# 305                                                NaN
# 306                                                NaN
# 307  일부 위원은 기준금리의 실효하한에 대해 다양한 견해가 있고 그 수준도 특정하기가 어...
# 308                                                NaN
# 309                                                NaN
#
#                                      Participant Views Government View  \
# 0                                                  NaN             NaN
# 1    일부 위원은 다음과 같은 점을 종합적으로 고려할 때 다음 결정시까지 콜금리 목표를 ...             NaN
# 2    일부 위원은 다음과 같은 점을 종합적으로 고려할 때 콜금리 목표를 0.25% 포인트...             NaN
# 3    일부 위원은 다음과 같은 점을 종합적으로 고려할 때 경기회복에 대한 확신이 아직은 ...             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 305                                                NaN             NaN
# 306                                                NaN             NaN
# 307  일부 위원은 이번 회의에서 기준금리를 0.50%로 25bp 인하하여 우리 경제에 대...             NaN
# 308                                                NaN             NaN
# 309                                                NaN             NaN
#
#      Economic Situation count  Foreign Currency count  \
# 0                           0                       0
# 1                          10                       5
# 2                          11                      12
# 3                           6                       4
# 4                           0                       0
# ..                        ...                     ...
# 305                         0                       0
# 306                         0                       0
# 307                        63                      74
# 308                         0                       0
# 309                         0                       0
#
#      Financial Markets count  Monetary Policy count  Participant Views count  \
# 0                          0                      0                        0
# 1                          2                     11                       47
# 2                          6                      6                       40
# 3                         11                     11                       42
# 4                          0                      0                        0
# ..                       ...                    ...                      ...
# 305                        0                      0                        0
# 306                        0                      0                        0
# 307                        0                     28                       97
# 308                        0                      0                        0
# 309                        0                      0                        0
#
#      Government View count                                              ngram
# 0                        0                                                NaN
# 1                        0  들/VV,국제/NNG,유가/NNG,크/VA,오르/VV,원화/NNG,엔/NNG,화간/...
# 2                        0  위안/NNG,절상/NNG,원화/NNG,절상/NNG,가장/MAG,크/VA,추가/NNG...
# 3                        0  금융/NNG,불안사태/NNG,발생/NNG,하/VV,가운데/NNG,국제/NNG,환투기...
# 4                        0                                                NaN
# ..                     ...                                                ...
# 305                      0                                                NaN
# 306                      0                                                NaN
# 307                      0  코로나/NNG,사태/NNG,이전/NNG,풍부/NNG,유동성/NNG,힘입/VV,미/N...
# 308                      0                                                NaN
# 309                      0                                                NaN
#
# [310 rows x 15 columns]

# %%
#섹션 2,3만 남기고 제거/ 해당 섹션 없는 의사록 제거
bok_section_2_3= tmp.drop(tmp[['Economic Situation','Monetary Policy','Participant Views','Government View', 'Economic Situation count', 'Monetary Policy count', 'Participant Views count', 'Government View count']], axis='columns')
bok_section_2_3 = bok_section_2_3[bok_section_2_3['ngram'].notna()]

#str타입의 날짜를 date 형식으로 변환
bok_section_2_3['new_date'] = bok_section_2_3['date'].apply(lambda x :datetime.strptime(x, '%Y-%m-%d') )
bok_section_2_3 = bok_section_2_3[bok_section_2_3['new_date'] <= datetime(2017, 12, 31, 0, 0, 0)]
bok_section_2_3
# Out:
#            date                                            minutes  \
# 1    2005-07-07  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 2    2005-08-11  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 3    2005-09-08  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 5    2005-10-11  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 6    2005-11-10  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# ..          ...                                                ...
# 251  2017-05-25  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 253  2017-07-13  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 255  2017-08-31  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 257  2017-10-19  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 259  2017-11-30  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
#
#                                       Foreign Currency  \
# 1    일부 위원은 6월 들어 국제유가가 크게 오르고 원화와 엔화간 동조화 현상이 뚜렷해지...
# 2    일부 위원은 위안화 절상 이후 아시아 통화중 우리나라 원화의 절상폭이 가장 컸다면서...
# 3    일부 위원은 최근 인도네시아 금융불안 사태가 발생한 가운데 국제 환투기세력이 인도네...
# 5    일부 위원은 미국과 우리나라의 정책금리 격차가 확대되고 있는 가운데 금년 두 차례 ...
# 6    일부 위원은 미 달러화에 대한 엔화 약세가 지속될 것으로 보는지 물었으며, 이에 대...
# ..                                                 ...
# 251  일부 위원은 최근 국제금융시장이 안정된 모습을 지속하는 가운데 국내금융시장도 외국인...
# 253  일부 위원은 주요국에서는 성장과 고용이 회복국면의 정점을 향해 가고 있음에도 불구하...
# 255  일부 위원은 미국의 금리 정상화 행보에도 불구하고 미 달러화가 약세기조를 지속하면서...
# 257  일부 위원은 최근 미국에서는 임금상승세가 확대되고 세제개혁에 대한 기대감이 커지면서...
# 259  일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를 인상할...
#
#                                      Financial Markets  \
# 1    일부 위원은 단기적으로 대출이 급격히 증가한 후에는 반드시 조정이 이어지고 민간소비...
# 2    일부 위원은 최근 장기시장금리 상승에도 불구하고 기업 자금조달은 오히려 확대되고 있...
# 3    일부 위원은 시장이 제대로 작동한다면 비우량등급의 회사채 가산금리가 사상 최저치를 ...
# 5    일부 위원은 8월말 이후 우리나라 주가지수가 큰 폭 상승한 것은 경제성장에 대한 낙...
# 6    일부 위원은 장단기금리 격차가 경제성장률에 선행하는 모습을 보인다고 하면 미국의 3...
# ..                                                 ...
# 251                                                NaN
# 253                                                NaN
# 255                                                NaN
# 257                                                NaN
# 259                                                NaN
#
#      Foreign Currency count  Financial Markets count  \
# 1                         5                        2
# 2                        12                        6
# 3                         4                       11
# 5                         4                        5
# 6                         8                        3
# ..                      ...                      ...
# 251                      31                        0
# 253                      26                        0
# 255                      38                        0
# 257                      43                        0
# 259                      34                        0
#
#                                                  ngram   new_date
# 1    들/VV,국제/NNG,유가/NNG,크/VA,오르/VV,원화/NNG,엔/NNG,화간/... 2005-07-07
# 2    위안/NNG,절상/NNG,원화/NNG,절상/NNG,가장/MAG,크/VA,추가/NNG... 2005-08-11
# 3    금융/NNG,불안사태/NNG,발생/NNG,하/VV,가운데/NNG,국제/NNG,환투기... 2005-09-08
# 5    금리갭/NNG,확대/NNG,되/XSV,가운데/NNG,남/VV,fed/NNG,금리/N... 2005-10-11
# 6    미/NNG,달러/NNG,엔/NNG,약세/NNG,지속/NNG,되/VV,보/VV,물/V... 2005-11-10
# ..                                                 ...        ...
# 251  국제/NNG,금융시장/NNG,안정/NNG,되/VV,지속/NNG,하/XSV,가운데/N... 2017-05-25
# 253  성장/NNG,고용/NNG,회복국면/NNG,정점/NNG,향하/VV,불구/NNG,물가/... 2017-07-13
# 255  금리정상화/NNG,행보/NNG,불구/NNG,미/NNG,달러/NNG,약세/NNG,기조... 2017-08-31
# 257  임금/NNG,상승/NNG,확대/NNG,되/XSV,세제/NNG,개혁/NNG,기대/NN... 2017-10-19
# 259  금융경제/NNG,보/VV,fed/NNG,금리/NNG,인상/NNG,하/VV,예견/NN... 2017-11-30
#
# [146 rows x 8 columns]

# %%
#섹션 2와 3, 그리고 ngram을 문장별로 분리해 따로 저장(후에 문장별로 라벨링하기 위한 작업), 편의를 위해 NaN자리에 ['0']을 넣음
bok_section_2_3_in_list = bok_section_2_3 
bok_section_2_3_in_list['Foreign Currency'] = bok_section_2_3['Foreign Currency'].apply(lambda x : x.split("@@@"))
bok_section_2_3_in_list['Financial Markets'] = bok_section_2_3['Financial Markets'].fillna("0")
bok_section_2_3_in_list['Financial Markets'] = bok_section_2_3['Financial Markets'].apply(lambda x : x.split("@@@"))
bok_section_2_3_in_list['ngram'] = bok_section_2_3['ngram'].apply(lambda x : x.split("@@@"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-0e29341b4e17> in <module>
#       1 #섹션 2와 3, 그리고 ngram을 문장별로 분리해 따로 저장(후에 문장별로 라벨링하기 위한 작업), 편의를 위해 NaN자리에 ['0']을 넣음
#       2 bok_section_2_3_in_list = bok_section_2_3
# ----> 3 bok_section_2_3_in_list['Foreign Currency'] = bok_section_2_3['Foreign Currency'].apply(lambda x : x.split("@@@"))
#       4 bok_section_2_3_in_list['Financial Markets'] = bok_section_2_3['Financial Markets'].fillna("0")
#       5 bok_section_2_3_in_list['Financial Markets'] = bok_section_2_3['Financial Markets'].apply(lambda x : x.split("@@@"))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-50-0e29341b4e17> in <lambda>(x)
#       1 #섹션 2와 3, 그리고 ngram을 문장별로 분리해 따로 저장(후에 문장별로 라벨링하기 위한 작업), 편의를 위해 NaN자리에 ['0']을 넣음
#       2 bok_section_2_3_in_list = bok_section_2_3
# ----> 3 bok_section_2_3_in_list['Foreign Currency'] = bok_section_2_3['Foreign Currency'].apply(lambda x : x.split("@@@"))
#       4 bok_section_2_3_in_list['Financial Markets'] = bok_section_2_3['Financial Markets'].fillna("0")
#       5 bok_section_2_3_in_list['Financial Markets'] = bok_section_2_3['Financial Markets'].apply(lambda x : x.split("@@@"))
#
# AttributeError: 'list' object has no attribute 'split'

# %%
bok_section_2_3_in_list
# Out:
#            date                                            minutes  \
# 1    2005-07-07  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 2    2005-08-11  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 3    2005-09-08  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 5    2005-10-11  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 6    2005-11-10  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# ..          ...                                                ...
# 251  2017-05-25  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 253  2017-07-13  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 255  2017-08-31  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 257  2017-10-19  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
# 259  2017-11-30  0      金融通貨委員會 議事錄\n\n\t\t\t\t\t\t\t\t\t\t\t\t...
#
#                                       Foreign Currency  \
# 1    [일부 위원은 6월 들어 국제유가가 크게 오르고 원화와 엔화간 동조화 현상이 뚜렷해...
# 2    [일부 위원은 위안화 절상 이후 아시아 통화중 우리나라 원화의 절상폭이 가장 컸다면...
# 3    [일부 위원은 최근 인도네시아 금융불안 사태가 발생한 가운데 국제 환투기세력이 인도...
# 5    [일부 위원은 미국과 우리나라의 정책금리 격차가 확대되고 있는 가운데 금년 두 차례...
# 6    [일부 위원은 미 달러화에 대한 엔화 약세가 지속될 것으로 보는지 물었으며, 이에 ...
# ..                                                 ...
# 251  [일부 위원은 최근 국제금융시장이 안정된 모습을 지속하는 가운데 국내금융시장도 외국...
# 253  [일부 위원은 주요국에서는 성장과 고용이 회복국면의 정점을 향해 가고 있음에도 불구...
# 255  [일부 위원은 미국의 금리 정상화 행보에도 불구하고 미 달러화가 약세기조를 지속하면...
# 257  [일부 위원은 최근 미국에서는 임금상승세가 확대되고 세제개혁에 대한 기대감이 커지면...
# 259  [일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를 인상...
#
#                                      Financial Markets  \
# 1    [일부 위원은 단기적으로 대출이 급격히 증가한 후에는 반드시 조정이 이어지고 민간소...
# 2    [일부 위원은 최근 장기시장금리 상승에도 불구하고 기업 자금조달은 오히려 확대되고 ...
# 3    [일부 위원은 시장이 제대로 작동한다면 비우량등급의 회사채 가산금리가 사상 최저치를...
# 5    [일부 위원은 8월말 이후 우리나라 주가지수가 큰 폭 상승한 것은 경제성장에 대한 ...
# 6    [일부 위원은 장단기금리 격차가 경제성장률에 선행하는 모습을 보인다고 하면 미국의 ...
# ..                                                 ...
# 251                                                [0]
# 253                                                [0]
# 255                                                [0]
# 257                                                [0]
# 259                                                [0]
#
#      Foreign Currency count  Financial Markets count  \
# 1                         5                        2
# 2                        12                        6
# 3                         4                       11
# 5                         4                        5
# 6                         8                        3
# ..                      ...                      ...
# 251                      31                        0
# 253                      26                        0
# 255                      38                        0
# 257                      43                        0
# 259                      34                        0
#
#                                                  ngram   new_date
# 1    [들/VV,국제/NNG,유가/NNG,크/VA,오르/VV,원화/NNG,엔/NNG,화간... 2005-07-07
# 2    [위안/NNG,절상/NNG,원화/NNG,절상/NNG,가장/MAG,크/VA,추가/NN... 2005-08-11
# 3    [금융/NNG,불안사태/NNG,발생/NNG,하/VV,가운데/NNG,국제/NNG,환투... 2005-09-08
# 5    [금리갭/NNG,확대/NNG,되/XSV,가운데/NNG,남/VV,fed/NNG,금리/... 2005-10-11
# 6    [미/NNG,달러/NNG,엔/NNG,약세/NNG,지속/NNG,되/VV,보/VV,물/... 2005-11-10
# ..                                                 ...        ...
# 251  [국제/NNG,금융시장/NNG,안정/NNG,되/VV,지속/NNG,하/XSV,가운데/... 2017-05-25
# 253  [성장/NNG,고용/NNG,회복국면/NNG,정점/NNG,향하/VV,불구/NNG,물가... 2017-07-13
# 255  [금리정상화/NNG,행보/NNG,불구/NNG,미/NNG,달러/NNG,약세/NNG,기... 2017-08-31
# 257  [임금/NNG,상승/NNG,확대/NNG,되/XSV,세제/NNG,개혁/NNG,기대/N... 2017-10-19
# 259  [금융경제/NNG,보/VV,fed/NNG,금리/NNG,인상/NNG,하/VV,예견/N... 2017-11-30
#
# [146 rows x 8 columns]
